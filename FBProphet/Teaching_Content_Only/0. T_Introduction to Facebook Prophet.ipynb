# %% [markdown]
# # 0. T_Introduction to Facebook Prophet
#
# This notebook includes the teacher's solutions to all the contents of the notebook '0. T_Introduction to Facebook Prophet'. This will also include any data proprocessing applied to create student datasets. It will also contain references for all the datasets used, and comments for why they were used.

# %%
import pandas as pd

path = '../Data/Teaching/synthetic'

df = pd.read_fwf(path,header = None)

df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000552  0.000387  0.000495  0.000564  0.000444  0.000485  0.000475
# 2  0.001103  0.000775  0.000990  0.001127  0.000888  0.000971  0.000950
# 3  0.001655  0.001162  0.001484  0.001690  0.001333  0.001456  0.001425
# 4  0.002207  0.001549  0.001979  0.002254  0.001777  0.001942  0.001901
#
#           7         8         9
# 0  0.000000  0.000000  0.000000
# 1  0.000490  0.000503  0.000430
# 2  0.000980  0.001006  0.000859
# 3  0.001470  0.001509  0.001288
# 4  0.001959  0.002012  0.001718

# %%
import matplotlib.pyplot as plt
